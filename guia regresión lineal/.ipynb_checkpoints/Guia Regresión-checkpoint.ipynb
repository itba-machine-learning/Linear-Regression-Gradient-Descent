# %% [markdown]
# # Guia regresión
# ## Consigna
# Para el dataset a continuación, calcular la regresión polinómica e ir variando el orden hasta obtener el resultado óptimo de AIC y BIC. También calcular $ R^2 $ y los p values.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm

# %%
x = np.load('X.npy')
y = np.load('y.npy')
plt.figure()
plt.plot(x, y, '.',  color='blue')
plt.title('Dataset')
plt.show()

# %% [markdown]
# ## Solución

# %%
def show_data(x, y, df, grado):
    model = sm.OLS(y, df).fit()
    plot(x, y, model.predict(), 'Grado ' + grado)
    print("=== pvalues ===")
    print(model.pvalues)
    print("AIC =>", model.aic)
    print("BIC =>", model.bic)
    print("======================================================================")

def plot(x, first_y, second_y, title='', first_color='blue', second_color='red'):
    plt.figure()
    plt.plot(x, first_y, '.',  color=first_color)
    plt.plot(x, second_y, c=second_color, linewidth=2)
    plt.title(title)
    plt.show()
    
def trim_train_test(df, percent=0.7):
    msk = np.random.rand(len(df)) < percent
    return df[msk], df[~msk]

# %% [markdown]
# ###### Graficamos y comparamos resultados de los primeros 10 grados

# %%
N = 10
train, test = trim_train_test(pd.DataFrame({0: x, 1: y}), 0.75)
train_potencies = pd.DataFrame()
test_potencies = pd.DataFrame()
for i in range(1, N + 1):
    train_potencies[i] = pow(train[0], i)
    test_potencies[i] = pow(test[0], i)
    show_data(train[0], train[1], train_potencies, str(i))
# Out:
# === pvalues ===
# 1    1.807308e-51
# dtype: float64
# AIC => 6373.443648840694
# BIC => 6377.365227260338
# ======================================================================
# === pvalues ===
# 1    1.977823e-101
# 2     2.922436e-84
# dtype: float64
# AIC => 5994.63778018376
# BIC => 6002.480937023048
# ======================================================================
# === pvalues ===
# 1     9.405059e-02
# 2    3.766567e-135
# 3     5.351257e-66
# dtype: float64
# AIC => 5699.432405986918
# BIC => 5711.197141245849
# ======================================================================
# === pvalues ===
# 1    1.003141e-01
# 2    1.535580e-20
# 3    4.321301e-66
# 4    1.721564e-01
# dtype: float64
# AIC => 5699.545580991687
# BIC => 5715.231894670262
# ======================================================================
# === pvalues ===
# 1    1.822054e-01
# 2    1.642786e-20
# 3    6.315943e-07
# 4    1.760185e-01
# 5    6.231012e-01
# dtype: float64
# AIC => 5701.30043360226
# BIC => 5720.908325700479
# ======================================================================
# === pvalues ===
# 1    1.785844e-01
# 2    1.531545e-04
# 3    5.783020e-07
# 4    3.507341e-01
# 5    6.010528e-01
# 6    4.849523e-01
# dtype: float64
# AIC => 5702.804078317829
# BIC => 5726.333548835692
# ======================================================================
# === pvalues ===
# 1    0.358560
# 2    0.000156
# 3    0.059011
# 4    0.352019
# 5    0.897590
# 6    0.486897
# 7    0.961713
# dtype: float64
# AIC => 5704.801726629737
# BIC => 5732.252775567244
# ======================================================================
# === pvalues ===
# 1    0.361678
# 2    0.253494
# 3    0.060300
# 4    0.190390
# 5    0.898397
# 6    0.245784
# 7    0.954919
# 8    0.281038
# dtype: float64
# AIC => 5705.612567664358
# BIC => 5736.985195021508
# ======================================================================
# === pvalues ===
# 1    0.210647
# 2    0.263065
# 3    0.102663
# 4    0.184272
# 5    0.389022
# 6    0.240041
# 7    0.390187
# 8    0.276522
# 9    0.390545
# dtype: float64
# AIC => 5706.85605712574
# BIC => 5742.150262902534
# ======================================================================
# === pvalues ===
# 1     0.197674
# 2     0.803363
# 3     0.094945
# 4     0.110092
# 5     0.366293
# 6     0.158655
# 7     0.365940
# 8     0.202411
# 9     0.365402
# 10    0.243297
# dtype: float64
# AIC => 5707.4552367340875
# BIC => 5746.671020930526
# ======================================================================

# %% [markdown]
# El de mejor performance comparando AIC y BIC es el de grado 3, aunque se puede observar que hay un pvalue que es mayor a 0.05<br />
# Por lo tanto quitamos esa columna y nos quedamos con la columna 2 y 3 y vemos que es cuando mejor performance obtenemos

# %%
train_potencies = train_potencies.iloc[:,1:3]
show_data(train[0], train[1], train_potencies, "3")
# Out:
# === pvalues ===
# 2    6.479921e-135
# 3    4.704870e-165
# dtype: float64
# AIC => 5700.262597348293
# BIC => 5708.105754187581
# ======================================================================

# %% [markdown]
# ###### Probamos el algoritmo con los datos de prueba

# %%
test_potencies = test_potencies.iloc[:,1:3]
show_data(test[0], test[1], test_potencies, "3")
# Out:
# === pvalues ===
# 2    5.298601e-42
# 3    1.078433e-55
# dtype: float64
# AIC => 1933.2660718167954
# BIC => 1938.9544459897127
# ======================================================================
